# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv('Social_Network_Ads.csv', sep=',')

# %%
data
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
data.head(10)
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0
# 5   27            58000          0
# 6   27            84000          0
# 7   32           150000          1
# 8   25            33000          0
# 9   35            65000          0

# %%
data.tail(10)
# Out:
#      Age  EstimatedSalary  Purchased
# 390   48            33000          1
# 391   47            23000          1
# 392   45            45000          1
# 393   60            42000          1
# 394   39            59000          0
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              400 non-null    int64
#  1   EstimatedSalary  400 non-null    int64
#  2   Purchased        400 non-null    int64
# dtypes: int64(3)
# memory usage: 9.5 KB

# %%
data.describe()
# Out:
#               Age  EstimatedSalary   Purchased
# count  400.000000       400.000000  400.000000
# mean    37.655000     69742.500000    0.357500
# std     10.482877     34096.960282    0.479864
# min     18.000000     15000.000000    0.000000
# 25%     29.750000     43000.000000    0.000000
# 50%     37.000000     70000.000000    0.000000
# 75%     46.000000     88000.000000    1.000000
# max     60.000000    150000.000000    1.000000

# %%
data.shape
# Out:
# (400, 3)

# %%
data.corr()
# Out:
#                       Age  EstimatedSalary  Purchased
# Age              1.000000         0.155238   0.622454
# EstimatedSalary  0.155238         1.000000   0.362083
# Purchased        0.622454         0.362083   1.000000

# %%
data[data['Age'] == max(data['Age'])]
# Out:
#      Age  EstimatedSalary  Purchased
# 215   60           108000          1
# 223   60           102000          1
# 272   60            42000          1
# 355   60            34000          1
# 370   60            46000          1
# 371   60            83000          1
# 393   60            42000          1

# %%
data[data['EstimatedSalary'] == max(data['EstimatedSalary'])]
# Out:
#      Age  EstimatedSalary  Purchased
# 7     32           150000          1
# 211   52           150000          1

# %%
data[data['Purchased'] == max(data['Purchased'])]
# Out:
#      Age  EstimatedSalary  Purchased
# 7     32           150000          1
# 16    47            25000          1
# 17    45            26000          1
# 18    46            28000          1
# 19    48            29000          1
# ..   ...              ...        ...
# 393   60            42000          1
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 399   49            36000          1
#
# [143 rows x 3 columns]

# %%
data[data['Age'] == min(data['Age'])]
# Out:
#      Age  EstimatedSalary  Purchased
# 14    18            82000          0
# 51    18            44000          0
# 76    18            52000          0
# 141   18            68000          0
# 165   18            86000          0

# %%
data[data['EstimatedSalary'] == min(data['EstimatedSalary'])]
# Out:
#      Age  EstimatedSalary  Purchased
# 43    30            15000          0
# 92    26            15000          0
# 150   26            15000          0
# 155   31            15000          0

# %%
data[data['Purchased'] == min(data['Purchased'])]
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 377   42            53000          0
# 380   42            64000          0
# 387   39            71000          0
# 394   39            59000          0
# 398   36            33000          0
#
# [257 rows x 3 columns]

# %%
plt.figure(figsize=(10,5))
sns.histplot(data['Age'], bins= 10)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.histplot(data['EstimatedSalary'], bins = 10)
plt.title('EstimatedSalary Distribution')
plt.xlabel('EstimatedSalary')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.histplot(data['Purchased'], bins = 10)
plt.title('Purchased Distribution')
plt.xlabel('Purchased')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize = (12,16))
plt.subplot(321)
plt.hist(data['Age'], bins = 20, color = 'orange', alpha = 1)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.subplot(322)
plt.hist(data['EstimatedSalary'], bins = 20, color = 'blue', alpha = 1)
plt.title('EstimatedSalary Distribution')
plt.xlabel('EstimatedSalary')
plt.subplot(323)
plt.hist(data['Purchased'], bins = 20, color = 'black', alpha = 1)
plt.title('Purchased Distribution')
plt.xlabel('Purchaed')
plt.show()

# %%
sns.boxplot(x = 'Purchased', y = 'Age', data = data)
plt.title('Age vs Purchased')
plt.show()

# %%
sns.boxplot(x = 'Purchased', y = 'EstimatedSalary', data = data)
plt.title('EstimatedSalary vs Purchased')
plt.show()

# %%
sns.boxplot(data = data[['Age', 'EstimatedSalary']])
plt.title('Boxplot of Age abd EstimatedSalary')
plt.show()

# %%
sns.scatterplot(x = 'Age', y = 'Purchased', data=data)
plt.title('Age Distribution vs. Purchased')
# Out:
# Text(0.5, 1.0, 'Age Distribution vs. Purchased')

# %%
sns.scatterplot(x = 'EstimatedSalary', y = 'Purchased', data= data)
plt.title('EstimatedSalary Distribution vs. Purchased')
# Out:
# Text(0.5, 1.0, 'EstimatedSalary Distribution vs. Purchased')

# %%
plt.figure(figsize = (12,4))
plt.subplot(121)
plt.scatter(data['Age'], data['Purchased'],color = 'orange', alpha = 1)
plt.title('Age vs. Purchased')
plt.xlabel('Age Distribution')
plt.ylabel('Purchased')
plt.subplot(122)
plt.scatter(data['EstimatedSalary'], data['Purchased'], color = 'blue', alpha =1)
plt.title('EstimatedSalary vs. Purchased')
plt.xlabel('EstimatedSalary Distribution')
plt.ylabel('Purchased')
# Out:
# Text(0, 0.5, 'Purchased')

# %%
plt.figure(figsize = (8,6))
sns.heatmap(data.corr(), annot = True, cmap = 'viridis')
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.pairplot(data)
plt.show()
